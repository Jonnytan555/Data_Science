# %% [markdown]
# #Spray Calculations

# %%
import pandas as pd
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file = '/content/drive/MyDrive/Programing/Colab Notebooks/Models and Data/spray.csv'
spray = pd.read_csv(file)

# %%
spray.fillna(0)
# Out:
#      Crank Angle(Degrees)  ...  Evaporated_fuel_for_one_portion
# 0                   340.0  ...                           0.0000
# 1                   340.2  ...                           0.0346
# 2                   340.4  ...                           0.0697
# 3                   340.6  ...                           0.1050
# 4                   340.8  ...                           0.1420
# ..                    ...  ...                              ...
# 752                 490.4  ...                           0.0000
# 753                 490.6  ...                           0.0000
# 754                 490.8  ...                           0.0000
# 755                 491.0  ...                           0.0000
# 756                 491.2  ...                           0.0000
#
# [757 rows x 16 columns]

# %%
spray.columns
# Out:
# Index(['Crank Angle(Degrees)', 'SMD', 'Spray_Angle', 'Spray_Tip_Pentration',
#        'Position_from_BDC', 'Heat_Release_Rate(J/deg)',
#        'Injection_Profile(dimensionless)', 'Heat_release_fraction',
#        'Fuel pressure_in_outlet_nozzle',
#        'Fuel velocity_in_outlet_of_nozzels(m/s)', 'Concentration_of_Nox',
#        'Combustion_Zone_temp(K)', 'Evaporated_fuel_fraction_in_zone_model',
#        'Cylinder_air_charge_usage_efficiency',
#        'Livengood-wu_integral_for_portion_1',
#        'Evaporated_fuel_for_one_portion'],
#       dtype='object')

# %%
spray.size
# Out:
# 12112

# %%
spray.describe()
# Out:
#        Crank Angle(Degrees)  ...  Evaporated_fuel_for_one_portion
# count            757.000000  ...                        26.000000
# mean             415.600000  ...                         0.481973
# std               43.734273  ...                         0.308496
# min              340.000000  ...                         0.000000
# 25%              377.800000  ...                         0.225250
# 50%              415.600000  ...                         0.471500
# 75%              453.400000  ...                         0.732250
# max              491.200000  ...                         1.000000
#
# [8 rows x 16 columns]

# %%
spray.corr()
# Out:
#                                          Crank Angle(Degrees)  ...  Evaporated_fuel_for_one_portion
# Crank Angle(Degrees)                                 1.000000  ...                         0.999478
# SMD                                                 -0.103554  ...                        -0.551682
# Spray_Angle                                         -0.541847  ...                        -0.781987
# Spray_Tip_Pentration                                 0.973790  ...                         0.982393
# Position_from_BDC                                    0.973790  ...                         0.982393
# Heat_Release_Rate(J/deg)                             0.973790  ...                         0.982393
# Injection_Profile(dimensionless)                     0.973790  ...                         0.982393
# Heat_release_fraction                                0.884908  ...                         0.734063
# ...

# %%
sb.heatmap(spray)

# %%
spray_variables = spray[['SMD', 'Spray_Angle','Spray_Tip_Pentration']]

# %%
plt.figure(figsize=(25,10))

for i in spray_variables.columns.values:
    plt.plot(spray_variables[i], label=i)
    plt.legend(spray_variables.columns,loc='best')
